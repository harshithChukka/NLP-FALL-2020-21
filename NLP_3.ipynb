# %%
import jieba
import nltk

# %%
seg = jieba.cut("把句子中所有的可以成词的词语都扫描出来",cut_all=True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\harsh\AppData\Local\Temp\jieba.cache
# Loading model cost 2.129 seconds.
# Prefix dict has been built successfully.
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %%
 #nltk.download('averaged_perceptron_tagger')

# %%
# TASK 1: Basic Text Processing Pipeline

import nltk
nltk.download('punkt')

texts = """Traditionally, work in natural language processing has tended to view the process of language analysis
as being decomposable into a number of stages, mirroring the theoretical linguistic distinctions drawn
between SYNTAX, SEMANTICS, and PRAGMATICS."""


for text in texts:
    sen = nltk.sent_tokenize(texts)
    
    for s in sen:
        words = nltk.word_tokenize(s)
        tag = nltk.pos_tag(words)
        print(tag)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\harsh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('Traditionally', 'RB'), (',', ','), ('work', 'NN'), ('in', 'IN'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('has', 'VBZ'), ('tended', 'VBN'), ('to', 'TO'), ('view', 'VB'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('language', 'NN'), ('analysis', 'NN'), ('as', 'IN'), ('being', 'VBG'), ('decomposable', 'JJ'), ('into', 'IN'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('stages', 'NNS'), (',', ','), ('mirroring', 'VBG'), ('the', 'DT'), ('theoretical', 'JJ'), ('linguistic', 'JJ'), ('distinctions', 'NNS'), ('drawn', 'VBP'), ('between', 'IN'), ('SYNTAX', 'NNP'), (',', ','), ('SEMANTICS', 'NNP'), (',', ','), ('and', 'CC'), ('PRAGMATICS', 'NNP'), ('.', '.')]
# ...

# %%
# TEXT 2: Tweet Tokenizer

from nltk.tokenize import TweetTokenizer

text = " I am learning NLP! #computerscience"
twtk = TweetTokenizer()
twtk.tokenize(text)
# Out:
# ['I', 'am', 'learning', 'NLP', '!', '#computerscience']

# %%
#TEXT 3: Scrapping Data from Web

from urllib import request

url = 'http://www.gutenberg.org/files/2554/2554-0.txt'
response = request.urlopen(url)
raw = response.read().decode('utf-8')
print(raw[:50])
# Out:
# ﻿The Project Gutenberg EBook of Crime and Punishme

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)

# %%
tokens[0:10]
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Crime',
#  'and',
#  'Punishment',
#  ',',
#  'by']
